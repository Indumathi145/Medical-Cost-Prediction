# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import matplotlib as mlt

# %%
# Importing dataset
df = pd.read_excel("Goal_14.xlsx")
df.head()
# Out:
#    Goal Target Indicator       SeriesCode  \
# 0    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 1    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 2    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 3    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 4    14   14.1    14.1.1  EN_MAR_BEALITSQ
#
#                             SeriesDescription  GeoAreaCode GeoAreaName  \
# 0  Beach litter per square kilometer (Number)            1       World
# 1  Beach litter per square kilometer (Number)            1       World
# 2  Beach litter per square kilometer (Number)            1       World
# 3  Beach litter per square kilometer (Number)            1       World
# 4  Beach litter per square kilometer (Number)            1       World
#
#    TimePeriod       Value Time_Detail   ...    Sampling Stations      Sex  \
# 0        2015    19618.00        2015   ...                  NaN  BOTHSEX
# 1        2016   405646.00        2016   ...                  NaN  BOTHSEX
# 2        2017   468426.00        2017   ...                  NaN  BOTHSEX
# 3        2018  1347138.00        2018   ...                  NaN  BOTHSEX
# 4        2019    10313.00        2019   ...                  NaN  BOTHSEX
#
#    Substance use disorders  Type of occupation Type of product  Type of skill  \
# 0                      NaN              isco08             ALP            NaN
# 1                      NaN              isco08             ALP            NaN
# 2                      NaN              isco08             ALP            NaN
# 3                      NaN              isco08             ALP            NaN
# 4                      NaN              isco08             ALP            NaN
#
#   Type of speed Type of support Type of waste treatment   Units
# 0          ANYS             NaN                     NaN  NUMBER
# 1          ANYS             NaN                     NaN  NUMBER
# 2          ANYS             NaN                     NaN  NUMBER
# 3          ANYS             NaN                     NaN  NUMBER
# 4          ANYS             NaN                     NaN  NUMBER
#
# [5 rows x 57 columns]

# %%
df.isnull().sum()
# Out:
# Goal                                            0
# Target                                          0
# Indicator                                       0
# SeriesCode                                      0
# SeriesDescription                               0
# GeoAreaCode                                     0
# GeoAreaName                                     0
# TimePeriod                                      0
# Value                                        4786
# Time_Detail                                     0
# TimeCoverage                                18507
# UpperBound                                  14237
# LowerBound                                  14237
# BasePeriod                                  18507
# Source                                        280
# GeoInfoUrl                                  18507
# FootNote                                    10691
# Activity                                    13846
# Age                                         13846
# Cause of death                              18507
# Cities                                      17992
# Counterpart                                 18507
# Disability status                           13846
# Education level                             13846
# Fiscal intervention stage                   18507
# Food Waste Sector                           18507
# Freq                                        13846
# Frequency of Chlorophyll-a concentration    17135
# Grounds of discrimination                   18507
# Hazard type                                 18507
# IHR Capacity                                18507
# Level of requirement                        18507
# Level/Status                                18507
# Location                                    13846
# Migratory status                            18507
# Mode of transportation                      18507
# Mountain Elevation                          18507
# Name of international institution           18507
# Name of non-communicable disease            18507
# Nature                                        939
# Observation Status                          13262
# Parliamentary committees                    18507
# Policy Domains                              18507
# Policy instruments                          18507
# Quantile                                    13846
# Report Ordinal                              18507
# Reporting Type                                  0
# Sampling Stations                           18032
# Sex                                         13846
# Substance use disorders                     18507
# Type of occupation                          13846
# Type of product                             13846
# Type of skill                               18507
# Type of speed                               17992
# Type of support                             18507
# Type of waste treatment                     18507
# Units                                           0
# dtype: int64

# %%
# To know the empty columns
df.count()
# Out:
# Goal                                        18507
# Target                                      18507
# Indicator                                   18507
# SeriesCode                                  18507
# SeriesDescription                           18507
# GeoAreaCode                                 18507
# GeoAreaName                                 18507
# TimePeriod                                  18507
# Value                                       13721
# Time_Detail                                 18507
# TimeCoverage                                    0
# UpperBound                                   4270
# LowerBound                                   4270
# BasePeriod                                      0
# Source                                      18227
# GeoInfoUrl                                      0
# FootNote                                     7816
# Activity                                     4661
# Age                                          4661
# Cause of death                                  0
# Cities                                        515
# Counterpart                                     0
# Disability status                            4661
# Education level                              4661
# Fiscal intervention stage                       0
# Food Waste Sector                               0
# Freq                                         4661
# Frequency of Chlorophyll-a concentration     1372
# Grounds of discrimination                       0
# Hazard type                                     0
# IHR Capacity                                    0
# Level of requirement                            0
# Level/Status                                    0
# Location                                     4661
# Migratory status                                0
# Mode of transportation                          0
# Mountain Elevation                              0
# Name of international institution               0
# Name of non-communicable disease                0
# Nature                                      17568
# Observation Status                           5245
# Parliamentary committees                        0
# Policy Domains                                  0
# Policy instruments                              0
# Quantile                                     4661
# Report Ordinal                                  0
# Reporting Type                              18507
# Sampling Stations                             475
# Sex                                          4661
# Substance use disorders                         0
# Type of occupation                           4661
# Type of product                              4661
# Type of skill                                   0
# Type of speed                                 515
# Type of support                                 0
# Type of waste treatment                         0
# Units                                       18507
# dtype: int64

# %%
# Removing empty columns
df1= df.drop(['TimeCoverage','Type of support','Type of waste treatment', 'Type of skill', 'Substance use disorders', 'Report Ordinal', 'Parliamentary committees', 'Policy Domains', 'Policy instruments', 'Migratory status', 'Mode of transportation', 'Mountain Elevation', 'Name of international institution','Name of non-communicable disease','Grounds of discrimination','Hazard type','IHR Capacity','Level of requirement','Level/Status','Fiscal intervention stage','Food Waste Sector','Counterpart','Cause of death','GeoInfoUrl','BasePeriod','TimeCoverage'],axis=1)
df1.head()
# Out:
#    Goal Target Indicator       SeriesCode  \
# 0    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 1    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 2    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 3    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 4    14   14.1    14.1.1  EN_MAR_BEALITSQ
#
#                             SeriesDescription  GeoAreaCode GeoAreaName  \
# 0  Beach litter per square kilometer (Number)            1       World
# 1  Beach litter per square kilometer (Number)            1       World
# 2  Beach litter per square kilometer (Number)            1       World
# 3  Beach litter per square kilometer (Number)            1       World
# 4  Beach litter per square kilometer (Number)            1       World
#
#    TimePeriod       Value Time_Detail   ...    Nature  Observation Status  \
# 0        2015    19618.00        2015   ...         E                   A
# 1        2016   405646.00        2016   ...         E                   A
# 2        2017   468426.00        2017   ...         E                   A
# 3        2018  1347138.00        2018   ...         E                   A
# 4        2019    10313.00        2019   ...         E                   A
#
#   Quantile Reporting Type Sampling Stations      Sex Type of occupation  \
# 0       _T              G               NaN  BOTHSEX             isco08
# 1       _T              G               NaN  BOTHSEX             isco08
# 2       _T              G               NaN  BOTHSEX             isco08
# 3       _T              G               NaN  BOTHSEX             isco08
# 4       _T              G               NaN  BOTHSEX             isco08
#
#   Type of product Type of speed   Units
# 0             ALP          ANYS  NUMBER
# 1             ALP          ANYS  NUMBER
# 2             ALP          ANYS  NUMBER
# 3             ALP          ANYS  NUMBER
# 4             ALP          ANYS  NUMBER
#
# [5 rows x 32 columns]

# %%
# Removing unsignificant columns
df2 = df1.drop(['Disability status','Activity','Education level','Quantile','Cities','Sex','Age','Type of product'], axis=1)
df2.head()
# Out:
#    Goal Target Indicator       SeriesCode  \
# 0    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 1    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 2    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 3    14   14.1    14.1.1  EN_MAR_BEALITSQ
# 4    14   14.1    14.1.1  EN_MAR_BEALITSQ
#
#                             SeriesDescription  GeoAreaCode GeoAreaName  \
# 0  Beach litter per square kilometer (Number)            1       World
# 1  Beach litter per square kilometer (Number)            1       World
# 2  Beach litter per square kilometer (Number)            1       World
# 3  Beach litter per square kilometer (Number)            1       World
# 4  Beach litter per square kilometer (Number)            1       World
#
#    TimePeriod       Value Time_Detail   ...      Freq  \
# 0        2015    19618.00        2015   ...    ANNUAL
# 1        2016   405646.00        2016   ...    ANNUAL
# 2        2017   468426.00        2017   ...    ANNUAL
# 3        2018  1347138.00        2018   ...    ANNUAL
# 4        2019    10313.00        2019   ...    ANNUAL
#
#    Frequency of Chlorophyll-a concentration Location Nature  \
# 0                                       NaN  ALLAREA      E
# 1                                       NaN  ALLAREA      E
# 2                                       NaN  ALLAREA      E
# 3                                       NaN  ALLAREA      E
# 4                                       NaN  ALLAREA      E
#
#   Observation Status Reporting Type Sampling Stations Type of occupation  \
# 0                  A              G               NaN             isco08
# 1                  A              G               NaN             isco08
# 2                  A              G               NaN             isco08
# 3                  A              G               NaN             isco08
# 4                  A              G               NaN             isco08
#
#   Type of speed   Units
# 0          ANYS  NUMBER
# 1          ANYS  NUMBER
# 2          ANYS  NUMBER
# 3          ANYS  NUMBER
# 4          ANYS  NUMBER
#
# [5 rows x 24 columns]

# %%
# Set indicator as index
df3 = df2.set_index(['Indicator'])
df3.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
#
#           GeoAreaName  TimePeriod       Value Time_Detail  UpperBound   ...    \
# Indicator                                                               ...
# 14.1.1          World        2015    19618.00        2015         NaN   ...
# 14.1.1          World        2016   405646.00        2016         NaN   ...
# 14.1.1          World        2017   468426.00        2017         NaN   ...
# 14.1.1          World        2018  1347138.00        2018         NaN   ...
# 14.1.1          World        2019    10313.00        2019         NaN   ...
#
#              Freq Frequency of Chlorophyll-a concentration Location Nature  \
# Indicator
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
#
#           Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1                     A              G               NaN
# 14.1.1                     A              G               NaN
# 14.1.1                     A              G               NaN
# 14.1.1                     A              G               NaN
# 14.1.1                     A              G               NaN
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
# Removing unsignicant indicators
df4= df3.drop(['14.4.1','14.6.1','14.7.1','14.b.1'])
df4.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
#
#           GeoAreaName  TimePeriod       Value Time_Detail  UpperBound   ...    \
# Indicator                                                               ...
# 14.1.1          World        2015    19618.00        2015         NaN   ...
# 14.1.1          World        2016   405646.00        2016         NaN   ...
# 14.1.1          World        2017   468426.00        2017         NaN   ...
# 14.1.1          World        2018  1347138.00        2018         NaN   ...
# 14.1.1          World        2019    10313.00        2019         NaN   ...
#
#              Freq Frequency of Chlorophyll-a concentration Location Nature  \
# Indicator
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
# 14.1.1     ANNUAL                                      NaN  ALLAREA      E
#
#           Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1                     A              G               NaN
# 14.1.1                     A              G               NaN
# 14.1.1                     A              G               NaN
# 14.1.1                     A              G               NaN
# 14.1.1                     A              G               NaN
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
df4.isnull().sum()
# Out:
# Goal                                            0
# Target                                          0
# SeriesCode                                      0
# SeriesDescription                               0
# GeoAreaCode                                     0
# GeoAreaName                                     0
# TimePeriod                                      0
# Value                                           0
# Time_Detail                                     0
# UpperBound                                   7181
# LowerBound                                   7181
# Source                                          0
# FootNote                                    10089
# Freq                                         6790
# Frequency of Chlorophyll-a concentration    10079
# Location                                     6790
# Nature                                        432
# Observation Status                           6790
# Reporting Type                                  0
# Sampling Stations                           10976
# Type of occupation                           6790
# Type of speed                               10936
# Units                                           0
# dtype: int64

# %%
df5 = df4.fillna(0)
df5.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
#
#           GeoAreaName  TimePeriod       Value Time_Detail  UpperBound   ...    \
# Indicator                                                               ...
# 14.1.1          World        2015    19618.00        2015         0.0   ...
# 14.1.1          World        2016   405646.00        2016         0.0   ...
# 14.1.1          World        2017   468426.00        2017         0.0   ...
# 14.1.1          World        2018  1347138.00        2018         0.0   ...
# 14.1.1          World        2019    10313.00        2019         0.0   ...
#
#              Freq Frequency of Chlorophyll-a concentration Location Nature  \
# Indicator
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
#
#           Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
df5.isnull().sum()
# Out:
# Goal                                        0
# Target                                      0
# SeriesCode                                  0
# SeriesDescription                           0
# GeoAreaCode                                 0
# GeoAreaName                                 0
# TimePeriod                                  0
# Value                                       0
# Time_Detail                                 0
# UpperBound                                  0
# LowerBound                                  0
# Source                                      0
# FootNote                                    0
# Freq                                        0
# Frequency of Chlorophyll-a concentration    0
# Location                                    0
# Nature                                      0
# Observation Status                          0
# Reporting Type                              0
# Sampling Stations                           0
# Type of occupation                          0
# Type of speed                               0
# Units                                       0
# dtype: int64

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11451 entries, 14.1.1 to 14.c.1
# Data columns (total 23 columns):
# Goal                                        11451 non-null int64
# Target                                      11451 non-null object
# SeriesCode                                  11451 non-null object
# SeriesDescription                           11451 non-null object
# GeoAreaCode                                 11451 non-null int64
# GeoAreaName                                 11451 non-null object
# TimePeriod                                  11451 non-null int64
# Value                                       11451 non-null object
# Time_Detail                                 11451 non-null object
# UpperBound                                  11451 non-null float64
# LowerBound                                  11451 non-null float64
# Source                                      11451 non-null object
# FootNote                                    11451 non-null object
# Freq                                        11451 non-null object
# Frequency of Chlorophyll-a concentration    11451 non-null object
# Location                                    11451 non-null object
# Nature                                      11451 non-null object
# Observation Status                          11451 non-null object
# Reporting Type                              11451 non-null object
# Sampling Stations                           11451 non-null object
# Type of occupation                          11451 non-null object
# Type of speed                               11451 non-null object
# Units                                       11451 non-null object
# dtypes: float64(2), int64(3), object(18)
# memory usage: 2.1+ MB

# %%
# Converting object to float
df5['Value'] = df5['Value'].astype(float)
df5['TimePeriod']= df5['TimePeriod'].astype(object)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11451 entries, 14.1.1 to 14.c.1
# Data columns (total 23 columns):
# Goal                                        11451 non-null int64
# Target                                      11451 non-null object
# SeriesCode                                  11451 non-null object
# SeriesDescription                           11451 non-null object
# GeoAreaCode                                 11451 non-null int64
# GeoAreaName                                 11451 non-null object
# TimePeriod                                  11451 non-null object
# Value                                       11451 non-null float64
# Time_Detail                                 11451 non-null object
# UpperBound                                  11451 non-null float64
# LowerBound                                  11451 non-null float64
# Source                                      11451 non-null object
# FootNote                                    11451 non-null object
# Freq                                        11451 non-null object
# Frequency of Chlorophyll-a concentration    11451 non-null object
# Location                                    11451 non-null object
# Nature                                      11451 non-null object
# Observation Status                          11451 non-null object
# Reporting Type                              11451 non-null object
# Sampling Stations                           11451 non-null object
# Type of occupation                          11451 non-null object
# Type of speed                               11451 non-null object
# Units                                       11451 non-null object
# dtypes: float64(3), int64(2), object(18)
# memory usage: 2.1+ MB

# %%
# Summary
df5.describe()
print("The summary")
# Out:
# The summary

# %%
df5['SeriesDescription'].unique()
# Out:
# array(['Beach litter per square kilometer (Number)',
#        'Chlorophyll-a anomaly, remote sensing (%)',
#        'Chlorophyll-a deviations, remote sensing (%)',
#        'Average marine acidity (pH) measured at agreed suite of representative sampling stations',
#        'Coverage of protected areas in relation to marine areas (Exclusive Economic Zones) (%)',
#        'Protected marine area (Exclusive Economic Zones) (square kilometres)',
#        'Average proportion of Marine Key Biodiversity Areas (KBAs) covered by protected areas (%)',
#        'National ocean science expenditure as a share of total research and development funding (%)',
#        'Score for the implementation of UNCLOS and its two implementing agreements (%)',
#        'Score for the ratification of and accession to UNCLOS and its two implementing agreements (%)'],
#       dtype=object)

# %%
## Creating dataframe for each indicator:
indi_14_1_1 = df5.loc['14.1.1']
indi_14_1_1.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
#
#           GeoAreaName TimePeriod      Value Time_Detail  UpperBound   ...    \
# Indicator                                                             ...
# 14.1.1          World       2015    19618.0        2015         0.0   ...
# 14.1.1          World       2016   405646.0        2016         0.0   ...
# 14.1.1          World       2017   468426.0        2017         0.0   ...
# 14.1.1          World       2018  1347138.0        2018         0.0   ...
# 14.1.1          World       2019    10313.0        2019         0.0   ...
#
#              Freq Frequency of Chlorophyll-a concentration Location Nature  \
# Indicator
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
#
#           Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
# Creating dataframe for by series description
indi_14_1_1= df5.loc[df5['SeriesDescription']=='Beach litter per square kilometer (Number)']
indi_14_1_1.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
# 14.1.1     Beach litter per square kilometer (Number)            1
#
#           GeoAreaName TimePeriod      Value Time_Detail  UpperBound   ...    \
# Indicator                                                             ...
# 14.1.1          World       2015    19618.0        2015         0.0   ...
# 14.1.1          World       2016   405646.0        2016         0.0   ...
# 14.1.1          World       2017   468426.0        2017         0.0   ...
# 14.1.1          World       2018  1347138.0        2018         0.0   ...
# 14.1.1          World       2019    10313.0        2019         0.0   ...
#
#              Freq Frequency of Chlorophyll-a concentration Location Nature  \
# Indicator
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
#
#           Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
indi_14_1_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 515 entries, 14.1.1 to 14.1.1
# Data columns (total 23 columns):
# Goal                                        515 non-null int64
# Target                                      515 non-null object
# SeriesCode                                  515 non-null object
# SeriesDescription                           515 non-null object
# GeoAreaCode                                 515 non-null int64
# GeoAreaName                                 515 non-null object
# TimePeriod                                  515 non-null object
# Value                                       515 non-null float64
# Time_Detail                                 515 non-null object
# UpperBound                                  515 non-null float64
# LowerBound                                  515 non-null float64
# Source                                      515 non-null object
# FootNote                                    515 non-null object
# Freq                                        515 non-null object
# Frequency of Chlorophyll-a concentration    515 non-null object
# Location                                    515 non-null object
# Nature                                      515 non-null object
# Observation Status                          515 non-null object
# Reporting Type                              515 non-null object
# Sampling Stations                           515 non-null object
# Type of occupation                          515 non-null object
# Type of speed                               515 non-null object
# Units                                       515 non-null object
# dtypes: float64(3), int64(2), object(18)
# memory usage: 96.6+ KB

# %%
series = ['Beach litter per square kilometer (Number)',
       'Chlorophyll-a anomaly, remote sensing (%)',
       'Chlorophyll-a deviations, remote sensing (%)',
       'Average marine acidity (pH) measured at agreed suite of representative sampling stations',
       'Coverage of protected areas in relation to marine areas (Exclusive Economic Zones) (%)',
       'Protected marine area (Exclusive Economic Zones) (square kilometres)',
       'Average proportion of Marine Key Biodiversity Areas (KBAs) covered by protected areas (%)',
       'National ocean science expenditure as a share of total research and development funding (%)',
       'Score for the implementation of UNCLOS and its two implementing agreements (%)',
       'Score for the ratification of and accession to UNCLOS and its two implementing agreements (%)']

# %%
## Pivot table for value grouped by year
df6=pd.pivot_table(indi_14_1_1,index=["GeoAreaName"],values=["Value"],columns = ["TimePeriod"])
cm = sns.light_palette("green", as_cmap=True)
df6.style.background_gradient(cmap=cm)
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row0_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row0_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row1_col0 {
#             background-color:  #389f38;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row1_col1 {
#             background-color:  #a8dda8;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row1_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row2_col0 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row2_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row2_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row3_col0 {
#             background-color:  #c9efc9;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row3_col2 {
#             background-color:  #dcfadc;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row3_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row3_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row3_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row4_col0 {
#             background-color:  #e3fee3;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row4_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row4_col2 {
#             background-color:  #e2fde2;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row4_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row4_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row5_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row5_col2 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row5_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row5_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row5_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row6_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row6_col2 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row6_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row6_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row6_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row7_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row7_col2 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row7_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row7_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row7_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row8_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row8_col2 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row8_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row8_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row8_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row9_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row9_col2 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row9_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row9_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row9_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row10_col1 {
#             background-color:  #008000;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row10_col2 {
#             background-color:  #d6f7d6;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row10_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row10_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row11_col0 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row11_col1 {
#             background-color:  #e4fee4;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row11_col2 {
#             background-color:  #dffcdf;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row11_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row11_col4 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row11_col5 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row12_col0 {
#             background-color:  #99d599;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row12_col1 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row12_col2 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row12_col3 {
#             background-color:  #e5ffe5;
#         }    #T_064d0b62_ae3d_11eb_bd97_a497b12e1436row12_col4

# %%
Geo_value = indi_14_1_1[["GeoAreaName","Value"]]
Geo_value_mean = Geo_value.groupby(Geo_value["GeoAreaName"]).mean().sort_values(by='Value', ascending=False)
Geo_value_mean
# Out:
#                                     Value
# GeoAreaName
# Ghana                        7.834713e+08
# Cameroon                     8.467962e+07
# Bangladesh                   5.219252e+07
# Seychelles                   4.336921e+07
# Algeria                      2.457958e+07
# United Republic of Tanzania  1.860295e+07
# Malawi                       1.821244e+07
# Colombia                     1.712477e+07
# Croatia                      1.528898e+07
# Serbia                       1.315116e+07
# Saint Helena                 8.249464e+06
# Peru                         7.849774e+06
# Marshall Islands             7.358689e+06
# Isle of Man                  6.200249e+06
# Cyprus                       6.037304e+06
# Georgia                      5.907671e+06
# Madagascar                   5.741935e+06
# Pakistan                     5.538922e+06
# Singapore                    5.452314e+06
# Nigeria                      5.074044e+06
# Costa Rica                   5.063799e+06
# Guatemala                    5.024037e+06
# Cambodia                     4.862885e+06
# Romania                      4.262947e+06
# Argentina                    4.228085e+06
# United Arab Emirates         3.994832e+06
# Italy                        3.888758e+06
# Jamaica                      3.735628e+06
# China                        3.686850e+06
# Central America              3.573532e+06
# ...                                   ...
# Namibia                      1.864110e+05
# Denmark                      1.739887e+05
# Timor-Leste                  1.725920e+05
# Cabo Verde                   1.649260e+05
# Northern Mariana Islands     1.643875e+05
# Azerbaijan                   1.545300e+05
# Americas                     1.492783e+05
# Austria                      1.484830e+05
# Jersey                       1.405880e+05
# Senegal                      1.154755e+05
# Western Asia                 1.036985e+05
# Europe and Northern America  1.004322e+05
# Northern America             9.536033e+04
# Finland                      9.346950e+04
# Australia and New Zealand    9.269375e+04
# Ireland                      9.157100e+04
# United States of America     9.154333e+04
# Australia                    9.003450e+04
# Czechia                      7.414450e+04
# Sao Tome and Principe        5.310700e+04
# Egypt                        5.085200e+04
# Kuwait                       2.422400e+04
# El Salvador                  1.367000e+04
# Sweden                       1.343250e+04
# Central Asia                 1.144900e+04
# Kazakhstan                   1.144900e+04
# Côte d'Ivoire                1.002200e+04
# Kiribati                     2.485000e+03
# Ethiopia                     2.485000e+03
# Sierra Leone                 6.210000e+02
#
# [170 rows x 1 columns]

# %% [markdown]
# The top 5 countries for target 1 are 'Ghana', 'Cameroon','Bangladesh', 'Seychelles','Algeria'
#
# The last 5 countries for target 1 'Sierra Leone','Ethiopia','Kiribati',"Côte d'Ivoire","Central Asia"

# %%
## PIVOT TABLE for value by index of country and time period (this plot is used for to plot)
df8=pd.pivot_table(indi_14_1_1,index=["GeoAreaName","TimePeriod"],values=["Value"])
df8.head()
cm = sns.light_palette("green", as_cmap=True)
df8.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row1_col0 {
#             background-color:  #e3fee3;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row2_col0 {
#             background-color:  #e2fde2;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row3_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row4_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row5_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row6_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row7_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row8_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row9_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row11_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row12_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row13_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row14_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row15_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row16_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row17_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row18_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row19_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row20_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row21_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row22_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row23_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row24_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row25_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row26_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row27_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row28_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row29_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row30_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row31_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row32_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row33_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row34_col0 {
#             background-color:  #d7f7d7;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row35_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row36_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row37_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row38_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row39_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row40_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row41_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row42_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row43_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row44_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row45_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row46_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row47_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row48_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row49_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row50_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row51_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row52_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row53_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row54_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row55_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row56_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row57_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row58_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row59_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row60_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row61_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row62_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row63_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row64_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row65_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row66_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row67_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row68_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row69_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row70_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row71_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row72_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row73_col0 {
#             background-color:  #e5ffe5;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row74_col0 {
#             background-color:  #ddfbdd;
#         }    #T_17e3e45c_ae81_11eb_ae67_a497b12e1436row75_col0 {
#             background-color:  #e5ffe5;
#         }

# %%
df9=pd.pivot_table(indi_14_1_1,index=["TimePeriod"],values=["Value"],columns = ["GeoAreaName"])
df9.head()
cm = sns.light_palette("blue", as_cmap=True)
df9.style.background_gradient(cmap=cm)
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\matplotlib\colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col0 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col1 {
#             background-color:  #1e1eff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col2 {
#             background-color:  #e2e2ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col3 {
#             background-color:  #2323ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col4 {
#             background-color:  #8585ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col5 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col6 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col7 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col8 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col9 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col10 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col11 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col12 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col13 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col14 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col15 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col16 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col17 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col18 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col19 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col20 {
#             background-color:  #e2e2ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col21 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col22 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col23 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col24 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col25 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col26 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col27 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col28 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col29 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col30 {
#             background-color:  #dfdfff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col31 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col32 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col33 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col34 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col35 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col36 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col37 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col38 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col39 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col40 {
#             background-color:  #9595ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col41 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col42 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col43 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col44 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col45 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col46 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col47 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col48 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col49 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col50 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col51 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col52 {
#             background-color:  #d4d4ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col53 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col54 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col55 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col56 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col57 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col58 {
#             background-color:  #dcdcff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col59 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col60 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col61 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col62 {
#             background-color:  #cacaff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col63 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col64 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col65 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col66 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col67 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col68 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col69 {
#             background-color:  #d9d9ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col70 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col71 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col72 {
#             background-color:  #0000ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col73 {
#             background-color:  #e5e5ff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col74 {
#             background-color:  #cfcfff;
#         }    #T_194aa3a4_ae81_11eb_8fc7_a497b12e1436row0_col75 {
#             background-color:  #e5e5ff;
#         }

# %%
# Defining function for line plot
def line_plot(GeoAreaName):
    data = df8.loc[GeoAreaName]

    plt.plot(data.index, data.values)

# %%
# a) Space fixed time varying
# PLot for Bulgaria country
line_plot('Ghana')
plt.title('Line plot for Ghana country')
plt.xlabel('Years')
plt.ylabel('Value')
# Out:
# Text(0,0.5,'Value')

# %%
# b) bothe time and space varying
# PLots for top 5 countries in 5th target
plt.figure(figsize = (12, 6))

countries = ['Ghana', 'Cameroon','Bangladesh', 'Seychelles','Algeria']

for country in countries:
    line_plot(country)
    
plt.title('Line plot for most polluted top 5 countries')
plt.xlabel('Years')
plt.ylabel('Beach litter amount per square kilometer')
plt.legend(countries)

# %%
# Time fixed and space varying

# %%
TI_indi14_1_1=indi_14_1_1.set_index('TimePeriod')

# %%
Geo14_1_2018=TI_indi14_1_1.loc[2018].reset_index(drop=True).set_index('GeoAreaName')
best5_14_1_2018=Geo14_1_2018.loc[['Ghana','Cameroon','Bangladesh', 'Seychelles','Algeria']]

# %%
plt.plot(best5_14_1_2018.index,best5_14_1_2018.Value)
plt.title('Line plot for time fixed and space varying')
plt.xlabel('Conutries')
plt.ylabel('Value')
# Out:
# Text(0,0.5,'Value')

# %%
# PLots for last 5 countries in 5th target
plt.figure(figsize = (18, 8))

countries = ['Sierra Leone','Ethiopia','Kiribati',"Côte d'Ivoire","Central Asia"]

for country in countries:
    line_plot(country)

plt.legend(countries)

# %% [markdown]
# ## Continent analysis:

# %%
df5['GeoAreaName'].unique()
# Out:
# array(['World', 'South America', 'Albania', 'Oceania', 'Algeria',
#        'Central America', 'Eastern Africa', 'Southern Africa', 'Americas',
#        'Northern America', 'Caribbean', 'Eastern Asia', 'Azerbaijan',
#        'Argentina', 'Southern Asia', 'South-Eastern Asia', 'Australia',
#        'Southern Europe', 'Austria', 'Bahamas', 'Bangladesh', 'Barbados',
#        'Australia and New Zealand', 'Belgium', 'Micronesia', 'Bermuda',
#        'Polynesia', 'Central and Southern Asia', 'Bosnia and Herzegovina',
#        'Brazil', 'Belize', 'British Virgin Islands', 'Brunei Darussalam',
#        'Bulgaria', 'Myanmar', 'Cambodia', 'Cameroon', 'Canada',
#        'Cabo Verde', 'Cayman Islands', 'Asia', 'Central Asia',
#        'Sri Lanka', 'Western Asia', 'Europe', 'Eastern Europe', 'Chile',
#        'Northern Europe', 'Western Europe', 'China', 'Colombia',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czechia', 'Denmark',
#        'Dominican Republic', 'Ecuador', 'El Salvador', 'Ethiopia',
#        'Estonia', 'Fiji', 'Finland', 'France', 'French Polynesia',
#        'Georgia', 'Germany', 'Ghana', 'Kiribati', 'Greece', 'Grenada',
#        'Guam', 'Guatemala', 'Guyana', 'Iceland', 'India', 'Indonesia',
#        'Ireland', 'Israel', 'Italy', "Côte d'Ivoire", 'Jamaica', 'Japan',
#        'Kazakhstan', 'Kenya', 'Republic of Korea', 'Kuwait',
#        'Latin America and the Caribbean', 'Lebanon', 'Luxembourg',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Malta',
#        'Mauritius', 'Mexico', 'Montenegro', 'Morocco', 'Mozambique',
#        'Oman', 'Europe and Northern America', 'Namibia', 'Netherlands',
#        'Curaçao', 'Sint Maarten (Dutch part)',
#        'Bonaire, Sint Eustatius and Saba', 'New Caledonia', 'Vanuatu',
#        'New Zealand', 'Nicaragua', 'Nigeria', 'Norway',
#        'Northern Mariana Islands', 'Micronesia (Federated States of)',
#        'Marshall Islands', 'Palau', 'Pakistan', 'Panama', 'Paraguay',
#        'Peru', 'Philippines', 'Poland', 'Portugal', 'Timor-Leste',
#        'Puerto Rico', 'Qatar', 'Réunion', 'Romania', 'Russian Federation',
#        'Saint Barthélemy', 'Saint Helena', 'Saint Kitts and Nevis',
#        'Saint Lucia', 'Saint Martin (French Part)',
#        'Saint Vincent and the Grenadines', 'Sao Tome and Principe',
#        'Senegal', 'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Viet Nam', 'Slovenia', 'South Africa', 'Spain', 'Suriname',
#        'Northern Africa and Western Asia', 'Sweden',
#        'Eastern and South-Eastern Asia', 'Switzerland', 'Thailand',
#        'Tonga', 'Trinidad and Tobago', 'United Arab Emirates', 'Tunisia',
#        'Turkey', 'Ukraine', 'Egypt',
#        'United Kingdom of Great Britain and Northern Ireland', 'Guernsey',
#        'Jersey', 'Isle of Man', 'United Republic of Tanzania',
#        'United States of America', 'United States Virgin Islands',
#        'Uruguay', 'Venezuela (Bolivarian Republic of)', 'Samoa', 'Africa',
#        'Northern Africa', 'American Samoa', 'Middle Africa', 'Angola',
#        'Antigua and Barbuda', 'Bahrain', 'Melanesia', 'Solomon Islands',
#        'Christmas Island', 'Cocos (Keeling) Islands', 'Comoros', 'Congo',
#        'Democratic Republic of the Congo', 'Cook Islands',
#        'Least Developed Countries (LDCs)', 'Sub-Saharan Africa', 'Benin',
#        'Dominica', 'Equatorial Guinea', 'Eritrea', 'Faroe Islands',
#        'French Guiana', 'Djibouti', 'Gabon', 'Gambia',
#        'State of Palestine', 'Greenland', 'Guadeloupe', 'Guinea', 'Haiti',
#        'Heard Island and McDonald Islands', 'Honduras',
#        'Iran (Islamic Republic of)', 'Iraq',
#        "Democratic People's Republic of Korea", 'Latvia', 'Liberia',
#        'Libya', 'Lithuania', 'Martinique', 'Mauritania', 'Monaco',
#        'Montserrat', 'Nauru', 'Aruba',
#        'Oceania (exc. Australia and New Zealand)', 'Niue',
#        'Norfolk Island', 'Papua New Guinea', 'Pitcairn', 'Guinea-Bissau',
#        'Anguilla', 'Saint Pierre and Miquelon', 'Saudi Arabia', 'Somalia',
#        'Small island developing States (SIDS)', 'Sudan',
#        'Syrian Arab Republic', 'Togo', 'Tokelau',
#        'Turks and Caicos Islands', 'Tuvalu', 'Wallis and Futuna Islands',
#        'Yemen', 'Bouvet Island', 'British Indian Ocean Territory',
#        'Mayotte', 'Falkland Islands (Malvinas)',
#        'South Georgia and the South Sandwich Islands',
#        'French Southern Territories', 'Gibraltar', 'Jordan',
#        'Landlocked developing countries (LLDCs)',
#        'United States Minor Outlying Islands', 'Western Sahara',
#        'Svalbard and Jan Mayen Islands', 'Turkmenistan',
#        'China, Hong Kong Special Administrative Region',
#        'China, Macao Special Administrative Region', 'Developing regions',
#        'Burundi', 'Belarus', 'Southern Asia (excluding India)',
#        'Caucasus and Central Asia',
#        'Eastern Asia (excluding Japan and China)', 'Liechtenstein',
#        'Western Asia (exc. Armenia, Azerbaijan, Cyprus, Israel and Georgia)',
#        'Developed regions (Europe, Cyprus, Israel, Northern America, Japan, Australia & New Zealand)',
#        'Eastern Asia (excluding Japan)', 'South Sudan',
#        'Sub-Saharan Africa (inc. Sudan)', 'Slovakia'], dtype=object)

# %%
#Dataframe for Australia continent
Aus = df5.loc[df5['GeoAreaName']=='Australia']
Aus.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1    EN_MAR_CHLANM
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1      Chlorophyll-a anomaly, remote sensing (%)           36
#
#           GeoAreaName TimePeriod         Value Time_Detail  UpperBound  \
# Indicator
# 14.1.1      Australia       2015    1514.00000        2015         0.0
# 14.1.1      Australia       2016    7202.00000        2016         0.0
# 14.1.1      Australia       2017  210440.00000        2017         0.0
# 14.1.1      Australia       2018  140982.00000        2018         0.0
# 14.1.1      Australia       2018       1.99759        2018         0.0
#
#             ...       Freq Frequency of Chlorophyll-a concentration Location  \
# Indicator   ...
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...          0                                     High        0
#
#           Nature Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  0              G                 0
#
#           Type of occupation Type of speed    Units
# Indicator
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                     0             0  PERCENT
#
# [5 rows x 23 columns]

# %%
# Dataframe for South America continent
SA = df5.loc[df5['GeoAreaName']=='South America']
SA.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)            5
# 14.1.1     Beach litter per square kilometer (Number)            5
# 14.1.1     Beach litter per square kilometer (Number)            5
# 14.1.1     Beach litter per square kilometer (Number)            5
# 14.1.1     Beach litter per square kilometer (Number)            5
#
#              GeoAreaName TimePeriod      Value Time_Detail  UpperBound  \
# Indicator
# 14.1.1     South America       2015  4842535.0        2015         0.0
# 14.1.1     South America       2016  1428214.0        2016         0.0
# 14.1.1     South America       2017  1366327.0        2017         0.0
# 14.1.1     South America       2018  1012389.0        2018         0.0
# 14.1.1     South America       2019      315.0        2019         0.0
#
#             ...      Freq Frequency of Chlorophyll-a concentration Location  \
# Indicator   ...
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
#
#           Nature Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
#Dataframe for Australia Northern America
NA=df5.loc[df5['GeoAreaName']=='Northern America']
NA.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)           21
# 14.1.1     Beach litter per square kilometer (Number)           21
# 14.1.1     Beach litter per square kilometer (Number)           21
# 14.1.1     Beach litter per square kilometer (Number)           21
# 14.1.1     Beach litter per square kilometer (Number)           21
#
#                 GeoAreaName TimePeriod     Value Time_Detail  UpperBound  \
# Indicator
# 14.1.1     Northern America       2015    7707.0        2015         0.0
# 14.1.1     Northern America       2016  203368.0        2016         0.0
# 14.1.1     Northern America       2017  222444.0        2017         0.0
# 14.1.1     Northern America       2018  135227.0        2018         0.0
# 14.1.1     Northern America       2019    1340.0        2019         0.0
#
#             ...      Freq Frequency of Chlorophyll-a concentration Location  \
# Indicator   ...
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
#
#           Nature Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
#Dataframe for Asia continent
Asia= df5.loc[df5['GeoAreaName']=='Asia']
Asia.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)          142
# 14.1.1     Beach litter per square kilometer (Number)          142
# 14.1.1     Beach litter per square kilometer (Number)          142
# 14.1.1     Beach litter per square kilometer (Number)          142
# 14.1.1     Beach litter per square kilometer (Number)          142
#
#           GeoAreaName TimePeriod      Value Time_Detail  UpperBound   ...    \
# Indicator                                                             ...
# 14.1.1           Asia       2015   619343.0        2015         0.0   ...
# 14.1.1           Asia       2016   402912.0        2016         0.0   ...
# 14.1.1           Asia       2017  1470047.0        2017         0.0   ...
# 14.1.1           Asia       2018   873113.0        2018         0.0   ...
# 14.1.1           Asia       2019     1119.0        2019         0.0   ...
#
#              Freq Frequency of Chlorophyll-a concentration Location Nature  \
# Indicator
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
#
#           Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
#Dataframe for Europe continent
Eur = df5.loc[df5['GeoAreaName']=='Europe']
Eur.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)          150
# 14.1.1     Beach litter per square kilometer (Number)          150
# 14.1.1     Beach litter per square kilometer (Number)          150
# 14.1.1     Beach litter per square kilometer (Number)          150
# 14.1.1     Beach litter per square kilometer (Number)          150
#
#           GeoAreaName TimePeriod     Value Time_Detail  UpperBound   ...    \
# Indicator                                                            ...
# 14.1.1         Europe       2016  857093.0        2016         0.0   ...
# 14.1.1         Europe       2017  108985.0        2017         0.0   ...
# 14.1.1         Europe       2018  336883.0        2018         0.0   ...
# 14.1.1         Europe       2019  273498.0        2019         0.0   ...
# 14.1.1         Europe       2020     624.0        2020         0.0   ...
#
#              Freq Frequency of Chlorophyll-a concentration Location Nature  \
# Indicator
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
# 14.1.1     ANNUAL                                        0  ALLAREA      E
#
#           Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
# 14.1.1                     A              G                 0
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
#Dataframe for Africa continent
Af = df5.loc[df5['GeoAreaName']=='Africa']
Af.head()
# Out:
#            Goal Target     SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_CHLANM
# 14.1.1       14   14.1  EN_MAR_CHLANM
# 14.1.1       14   14.1  EN_MAR_CHLANM
# 14.1.1       14   14.1  EN_MAR_CHLANM
# 14.1.1       14   14.1  EN_MAR_CHLANM
#
#                                    SeriesDescription  GeoAreaCode GeoAreaName  \
# Indicator
# 14.1.1     Chlorophyll-a anomaly, remote sensing (%)            2      Africa
# 14.1.1     Chlorophyll-a anomaly, remote sensing (%)            2      Africa
# 14.1.1     Chlorophyll-a anomaly, remote sensing (%)            2      Africa
# 14.1.1     Chlorophyll-a anomaly, remote sensing (%)            2      Africa
# 14.1.1     Chlorophyll-a anomaly, remote sensing (%)            2      Africa
#
#           TimePeriod    Value Time_Detail  UpperBound   ...     Freq  \
# Indicator                                               ...
# 14.1.1          2018  3.92056        2018         0.0   ...        0
# 14.1.1          2018  3.18330        2018         0.0   ...        0
# 14.1.1          2019  2.71525        2019         0.0   ...        0
# 14.1.1          2019  3.28754        2019         0.0   ...        0
# 14.1.1          2020  2.74881        2020         0.0   ...        0
#
#           Frequency of Chlorophyll-a concentration Location Nature  \
# Indicator
# 14.1.1                                    Moderate        0      E
# 14.1.1                                        High        0      E
# 14.1.1                                        High        0      E
# 14.1.1                                    Moderate        0      E
# 14.1.1                                    Moderate        0      E
#
#           Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1                     0              G                 0
# 14.1.1                     0              G                 0
# 14.1.1                     0              G                 0
# 14.1.1                     0              G                 0
# 14.1.1                     0              G                 0
#
#           Type of occupation Type of speed    Units
# Indicator
# 14.1.1                     0             0  PERCENT
# 14.1.1                     0             0  PERCENT
# 14.1.1                     0             0  PERCENT
# 14.1.1                     0             0  PERCENT
# 14.1.1                     0             0  PERCENT
#
# [5 rows x 23 columns]

# %%
#Dataframe for Antarctica continent
df5.loc[df5['GeoAreaName']=='Antarctica']
# Out:
# Empty DataFrame
# Columns: [Goal, Target, SeriesCode, SeriesDescription, GeoAreaCode, GeoAreaName, TimePeriod, Value, Time_Detail, UpperBound, LowerBound, Source, FootNote, Freq, Frequency of Chlorophyll-a concentration, Location, Nature, Observation Status, Reporting Type, Sampling Stations, Type of occupation, Type of speed, Units]
# Index: []
#
# [0 rows x 23 columns]

# %%
# Dataframe for all continent
continent=pd.concat([Aus, SA, NA, Eur, Asia, Af], axis=0)
continent.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1    EN_MAR_CHLANM
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1      Chlorophyll-a anomaly, remote sensing (%)           36
#
#           GeoAreaName TimePeriod         Value Time_Detail  UpperBound  \
# Indicator
# 14.1.1      Australia       2015    1514.00000        2015         0.0
# 14.1.1      Australia       2016    7202.00000        2016         0.0
# 14.1.1      Australia       2017  210440.00000        2017         0.0
# 14.1.1      Australia       2018  140982.00000        2018         0.0
# 14.1.1      Australia       2018       1.99759        2018         0.0
#
#             ...       Freq Frequency of Chlorophyll-a concentration Location  \
# Indicator   ...
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...          0                                     High        0
#
#           Nature Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  0              G                 0
#
#           Type of occupation Type of speed    Units
# Indicator
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                     0             0  PERCENT
#
# [5 rows x 23 columns]

# %%
## Indicator 14.1.1 for continents
continent14_1 = continent.loc['14.1.1']
continent14_1.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1    EN_MAR_CHLANM
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1      Chlorophyll-a anomaly, remote sensing (%)           36
#
#           GeoAreaName TimePeriod         Value Time_Detail  UpperBound  \
# Indicator
# 14.1.1      Australia       2015    1514.00000        2015         0.0
# 14.1.1      Australia       2016    7202.00000        2016         0.0
# 14.1.1      Australia       2017  210440.00000        2017         0.0
# 14.1.1      Australia       2018  140982.00000        2018         0.0
# 14.1.1      Australia       2018       1.99759        2018         0.0
#
#             ...       Freq Frequency of Chlorophyll-a concentration Location  \
# Indicator   ...
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...          0                                     High        0
#
#           Nature Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  0              G                 0
#
#           Type of occupation Type of speed    Units
# Indicator
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                     0             0  PERCENT
#
# [5 rows x 23 columns]

# %%
# Indicator14.1.1 for all continent
con14_1=continent14_1.loc[continent14_1['SeriesDescription']=="Beach litter per square kilometer (Number)"]
con14_1.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)           36
# 14.1.1     Beach litter per square kilometer (Number)            5
#
#              GeoAreaName TimePeriod      Value Time_Detail  UpperBound  \
# Indicator
# 14.1.1         Australia       2015     1514.0        2015         0.0
# 14.1.1         Australia       2016     7202.0        2016         0.0
# 14.1.1         Australia       2017   210440.0        2017         0.0
# 14.1.1         Australia       2018   140982.0        2018         0.0
# 14.1.1     South America       2015  4842535.0        2015         0.0
#
#             ...      Freq Frequency of Chlorophyll-a concentration Location  \
# Indicator   ...
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
# 14.1.1      ...    ANNUAL                                        0  ALLAREA
#
#           Nature Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
#
#           Type of occupation Type of speed   Units
# Indicator
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
# 14.1.1                isco08          ANYS  NUMBER
#
# [5 rows x 23 columns]

# %%
con14_1['GeoAreaName'].unique()
# Out:
# array(['Australia', 'South America', 'Northern America', 'Europe', 'Asia'],
#       dtype=object)

# %%
con_pivot14_1=pd.pivot_table(con14_1,index=["GeoAreaName","TimePeriod"],values=["Value"])
con_pivot14_1
# Out:
#                                  Value
# GeoAreaName      TimePeriod
# Asia             2015         619343.0
#                  2016         402912.0
#                  2017        1470047.0
#                  2018         873113.0
#                  2019           1119.0
#                  2020            364.0
# Australia        2015           1514.0
#                  2016           7202.0
#                  2017         210440.0
#                  2018         140982.0
# Europe           2016         857093.0
#                  2017         108985.0
#                  2018         336883.0
#                  2019         273498.0
#                  2020            624.0
# Northern America 2015           7707.0
#                  2016         203368.0
#                  2017         222444.0
#                  2018         135227.0
#                  2019           1340.0
#                  2020           2076.0
# South America    2015        4842535.0
#                  2016        1428214.0
#                  2017        1366327.0
#                  2018        1012389.0
#                  2019            315.0

# %%
sd=sns.distplot(Asia["Value"], bins=10)
sd.set(title='The distribution plot for Asia')
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# [Text(0.5,1,'The distribution plot for Asia')]

# %%
s =sns.distplot(Aus["Value"], bins=10)
s.set(title='The distribution plot for Australia')
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# [Text(0.5,1,'The distribution plot for Australia')]

# %%
d=sns.distplot(Eur["Value"], bins=10)
d.set(title='The distribution plot for Europe')
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# [Text(0.5,1,'The distribution plot for Europe')]

# %%
i=sns.distplot(NA["Value"], bins=10)
i.set(title='The distribution plot for North America')
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# [Text(0.5,1,'The distribution plot for North America')]

# %%
j=sns.distplot(SA["Value"], bins=10)
j.set(title='The distribution plot for South America')
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# [Text(0.5,1,'The distribution plot for South America')]

# %%
plt.figure(figsize=(9, 6))
plt.bar(con14_1.GeoAreaName,con14_1.Value, color ='blue',width = 0.4)
plt.title('Bar plot of values of continent')
# Out:
# Text(0.5,1,'Bar plot of values of continent')

# %% [markdown]
# ## Time Series Analysis for continents

# %%
#converting string date time into python date time object
con14_1['TimePeriod'] = pd.to_datetime(con14_1['TimePeriod'],format='%Y', errors='coerce')
# Out:
# C:\Users\Pooja\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Setting date as index
con14_1_new=con14_1.set_index('TimePeriod')
con14_1_new.head()
# Out:
#             Goal Target       SeriesCode  \
# TimePeriod
# 2015-01-01    14   14.1  EN_MAR_BEALITSQ
# 2016-01-01    14   14.1  EN_MAR_BEALITSQ
# 2017-01-01    14   14.1  EN_MAR_BEALITSQ
# 2018-01-01    14   14.1  EN_MAR_BEALITSQ
# 2015-01-01    14   14.1  EN_MAR_BEALITSQ
#
#                                      SeriesDescription  GeoAreaCode  \
# TimePeriod
# 2015-01-01  Beach litter per square kilometer (Number)           36
# 2016-01-01  Beach litter per square kilometer (Number)           36
# 2017-01-01  Beach litter per square kilometer (Number)           36
# 2018-01-01  Beach litter per square kilometer (Number)           36
# 2015-01-01  Beach litter per square kilometer (Number)            5
#
#               GeoAreaName      Value Time_Detail  UpperBound  LowerBound  \
# TimePeriod
# 2015-01-01      Australia     1514.0        2015         0.0         0.0
# 2016-01-01      Australia     7202.0        2016         0.0         0.0
# 2017-01-01      Australia   210440.0        2017         0.0         0.0
# 2018-01-01      Australia   140982.0        2018         0.0         0.0
# 2015-01-01  South America  4842535.0        2015         0.0         0.0
#
#              ...      Freq Frequency of Chlorophyll-a concentration Location  \
# TimePeriod   ...
# 2015-01-01   ...    ANNUAL                                        0  ALLAREA
# 2016-01-01   ...    ANNUAL                                        0  ALLAREA
# 2017-01-01   ...    ANNUAL                                        0  ALLAREA
# 2018-01-01   ...    ANNUAL                                        0  ALLAREA
# 2015-01-01   ...    ANNUAL                                        0  ALLAREA
#
#            Nature Observation Status Reporting Type Sampling Stations  \
# TimePeriod
# 2015-01-01      E                  A              G                 0
# 2016-01-01      E                  A              G                 0
# 2017-01-01      E                  A              G                 0
# 2018-01-01      E                  A              G                 0
# 2015-01-01      E                  A              G                 0
#
#            Type of occupation Type of speed   Units
# TimePeriod
# 2015-01-01             isco08          ANYS  NUMBER
# 2016-01-01             isco08          ANYS  NUMBER
# 2017-01-01             isco08          ANYS  NUMBER
# 2018-01-01             isco08          ANYS  NUMBER
# 2015-01-01             isco08          ANYS  NUMBER
#
# [5 rows x 22 columns]

# %%
con14_1_Asia= con14_1_new.loc[con14_1_new['GeoAreaName']=='Asia']
con14_1_Aus= con14_1_new.loc[con14_1_new['GeoAreaName']=='Australia']
con14_1_Eur= con14_1_new.loc[con14_1_new['GeoAreaName']=='Europe']
con14_1_NA= con14_1_new.loc[con14_1_new['GeoAreaName']=='Northern America']
con14_1_SA= con14_1_new.loc[con14_1_new['GeoAreaName']=='South America']

# %%
# Lag plot:

from pandas.plotting import lag_plot
lag_plot(con14_1['Value'])
plt.title("Lag plot for lag 1")
plt.show()

# %%
# Autocorrelation plot 
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(con14_1['Value'])
plt.title('The autocorrelation plot for contients')
plt.show()

# %%
# Trend seasonal plot for Asia
from pylab import rcParams
import statsmodels.api as sm
plt.rcParams["figure.figsize"] = [12,6]
decomposition = sm.tsa.seasonal_decompose(con14_1_Asia['Value'], model='Additive', freq =2)
fig = decomposition.plot()
plt.title('Seasonal plot for Asia')
plt.show()

# %%
# Trend seasonal plot for Australia
from pylab import rcParams
import statsmodels.api as sm
plt.rcParams["figure.figsize"] = [14,6]
decomposition = sm.tsa.seasonal_decompose(con14_1_Aus['Value'], model='Additive', freq =2)
fig = decomposition.plot()
plt.show()

# %%
# Trend seasonal plot for Europe
from pylab import rcParams
import statsmodels.api as sm
plt.rcParams["figure.figsize"] = [14,6]
decomposition = sm.tsa.seasonal_decompose(con14_1_Eur['Value'], model='Additive', freq =2)
fig = decomposition.plot()
plt.show()

# %%
# Trend seasonal plot for North America
from pylab import rcParams
import statsmodels.api as sm
plt.rcParams["figure.figsize"] = [14,6]
decomposition = sm.tsa.seasonal_decompose(con14_1_NA['Value'], model='Additive', freq =2)
fig = decomposition.plot()
plt.show()

# %%
# Trend seasonal plot for South America
from pylab import rcParams
import statsmodels.api as sm
plt.rcParams["figure.figsize"] = [10,6]
decomposition = sm.tsa.seasonal_decompose(con14_1_SA['Value'], model='Additive', freq =2)
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ## Spacio Temproal Analysis

# %%
con14_1_1_1=con14_1_new.loc['2018-01-01'].reset_index(drop=True).set_index('GeoAreaName')
con14_1_1_1
# Out:
#                   Goal Target       SeriesCode  \
# GeoAreaName
# Australia           14   14.1  EN_MAR_BEALITSQ
# South America       14   14.1  EN_MAR_BEALITSQ
# Northern America    14   14.1  EN_MAR_BEALITSQ
# Europe              14   14.1  EN_MAR_BEALITSQ
# Asia                14   14.1  EN_MAR_BEALITSQ
#
#                                            SeriesDescription  GeoAreaCode  \
# GeoAreaName
# Australia         Beach litter per square kilometer (Number)           36
# South America     Beach litter per square kilometer (Number)            5
# Northern America  Beach litter per square kilometer (Number)           21
# Europe            Beach litter per square kilometer (Number)          150
# Asia              Beach litter per square kilometer (Number)          142
#
#                       Value Time_Detail  UpperBound  LowerBound  \
# GeoAreaName
# Australia          140982.0        2018         0.0         0.0
# South America     1012389.0        2018         0.0         0.0
# Northern America   135227.0        2018         0.0         0.0
# Europe             336883.0        2018         0.0         0.0
# Asia               873113.0        2018         0.0         0.0
#
#                                                Source   ...      Freq  \
# GeoAreaName                                             ...
# Australia         Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
# South America     Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
# Northern America  Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
# Europe            Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
# Asia              Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
#
#                  Frequency of Chlorophyll-a concentration Location Nature  \
# GeoAreaName
# Australia                                               0  ALLAREA      E
# South America                                           0  ALLAREA      E
# Northern America                                        0  ALLAREA      E
# Europe                                                  0  ALLAREA      E
# Asia                                                    0  ALLAREA      E
#
#                  Observation Status Reporting Type Sampling Stations  \
# GeoAreaName
# Australia                         A              G                 0
# South America                     A              G                 0
# Northern America                  A              G                 0
# Europe                            A              G                 0
# Asia                              A              G                 0
#
#                  Type of occupation Type of speed   Units
# GeoAreaName
# Australia                    isco08          ANYS  NUMBER
# South America                isco08          ANYS  NUMBER
# Northern America             isco08          ANYS  NUMBER
# Europe                       isco08          ANYS  NUMBER
# Asia                         isco08          ANYS  NUMBER
#
# [5 rows x 21 columns]

# %%
# Defining function for line plot
def con_line_plot(GeoAreaName):
    data2 = con_pivot14_1.loc[GeoAreaName]
    
    plt.plot(data2.index, data2.values)

# %%
# a) space fixed and time varying
con_line_plot('Asia')
plt.rcParams["figure.figsize"] = [9,6]
plt.title('Line plot for Asia')
# Out:
# Text(0.5,1,'Line plot for Asia')

# %%
# b) Both time and space varying

plt.figure(figsize = (11,7))

continents = ['Asia', 'Australia','Europe', 'Northern America','South America']

for countinent in continents:
    plt.title("Line plot of five continents for beach litter indicator")
    plt.xlabel('Years')
    plt.ylabel('Beach litter per square kilometer')
    con_line_plot(countinent)

plt.legend(continents)

# %%
con14_1_1_1=con14_1_new.loc['2018-01-01'].reset_index(drop=True).set_index('GeoAreaName')
con14_1_1_1
# Out:
#                   Goal Target       SeriesCode  \
# GeoAreaName
# Australia           14   14.1  EN_MAR_BEALITSQ
# South America       14   14.1  EN_MAR_BEALITSQ
# Northern America    14   14.1  EN_MAR_BEALITSQ
# Europe              14   14.1  EN_MAR_BEALITSQ
# Asia                14   14.1  EN_MAR_BEALITSQ
#
#                                            SeriesDescription  GeoAreaCode  \
# GeoAreaName
# Australia         Beach litter per square kilometer (Number)           36
# South America     Beach litter per square kilometer (Number)            5
# Northern America  Beach litter per square kilometer (Number)           21
# Europe            Beach litter per square kilometer (Number)          150
# Asia              Beach litter per square kilometer (Number)          142
#
#                       Value Time_Detail  UpperBound  LowerBound  \
# GeoAreaName
# Australia          140982.0        2018         0.0         0.0
# South America     1012389.0        2018         0.0         0.0
# Northern America   135227.0        2018         0.0         0.0
# Europe             336883.0        2018         0.0         0.0
# Asia               873113.0        2018         0.0         0.0
#
#                                                Source   ...      Freq  \
# GeoAreaName                                             ...
# Australia         Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
# South America     Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
# Northern America  Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
# Europe            Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
# Asia              Plastic Pollution (MLW, MDMAP, ICC)   ...    ANNUAL
#
#                  Frequency of Chlorophyll-a concentration Location Nature  \
# GeoAreaName
# Australia                                               0  ALLAREA      E
# South America                                           0  ALLAREA      E
# Northern America                                        0  ALLAREA      E
# Europe                                                  0  ALLAREA      E
# Asia                                                    0  ALLAREA      E
#
#                  Observation Status Reporting Type Sampling Stations  \
# GeoAreaName
# Australia                         A              G                 0
# South America                     A              G                 0
# Northern America                  A              G                 0
# Europe                            A              G                 0
# Asia                              A              G                 0
#
#                  Type of occupation Type of speed   Units
# GeoAreaName
# Australia                    isco08          ANYS  NUMBER
# South America                isco08          ANYS  NUMBER
# Northern America             isco08          ANYS  NUMBER
# Europe                       isco08          ANYS  NUMBER
# Asia                         isco08          ANYS  NUMBER
#
# [5 rows x 21 columns]

# %%
# Time fixed(2018) and space varing
plt.plot(con14_1_1_1.index,con14_1_1_1.Value)

# %% [markdown]
# ## India Analysis

# %%
df_i= df5.loc[df5['GeoAreaName']=='India']
df_i.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1    EN_MAR_CHLANM
# 14.1.1       14   14.1    EN_MAR_CHLANM
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)          356
# 14.1.1     Beach litter per square kilometer (Number)          356
# 14.1.1     Beach litter per square kilometer (Number)          356
# 14.1.1      Chlorophyll-a anomaly, remote sensing (%)          356
# 14.1.1      Chlorophyll-a anomaly, remote sensing (%)          356
#
#           GeoAreaName TimePeriod         Value Time_Detail  UpperBound  \
# Indicator
# 14.1.1          India       2016  883222.00000        2016         0.0
# 14.1.1          India       2017  916969.00000        2017         0.0
# 14.1.1          India       2018  172809.00000        2018         0.0
# 14.1.1          India       2018       0.99071        2018         0.0
# 14.1.1          India       2018       1.44438        2018         0.0
#
#             ...       Freq Frequency of Chlorophyll-a concentration Location  \
# Indicator   ...
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...          0                                     High        0
# 14.1.1      ...          0                                 Moderate        0
#
#           Nature Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  0              G                 0
# 14.1.1         E                  0              G                 0
#
#           Type of occupation Type of speed    Units
# Indicator
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                     0             0  PERCENT
# 14.1.1                     0             0  PERCENT
#
# [5 rows x 23 columns]

# %%
df_i= df5.loc[df5['GeoAreaName']=='India']
Ind_pivot14_1=pd.pivot_table(df_i,index=["SeriesDescription","TimePeriod"],values=["Value"])
Ind_pivot14_1
# Out:
#                                                                        Value
# SeriesDescription                                  TimePeriod
# Average proportion of Marine Key Biodiversity A... 2000            18.802590
#                                                    2001            18.802590
#                                                    2002            18.802590
#                                                    2003            18.802590
#                                                    2004            18.802590
#                                                    2005            18.802590
#                                                    2006            18.802590
#                                                    2007            18.802590
#                                                    2008            18.802590
#                                                    2009            18.802590
#                                                    2010            18.802590
#                                                    2011            18.802590
#                                                    2012            18.802590
#                                                    2013            18.802590
#                                                    2014            18.802590
#                                                    2015            18.802590
#                                                    2016            18.802590
#                                                    2017            18.802590
#                                                    2018            18.802590
#                                                    2019            18.802590
# Beach litter per square kilometer (Number)         2016        883222.000000
#                                                    2017        916969.000000
#                                                    2018        172809.000000
# Chlorophyll-a anomaly, remote sensing (%)          2018             1.217545
#                                                    2019             1.858785
#                                                    2020             1.686675
# Chlorophyll-a deviations, remote sensing (%)       2000             3.360000
#                                                    2001             4.180000
#                                                    2002             4.640000
#                                                    2003             3.560000
#                                                    2004             4.760000
#                                                    2005             5.690000
#                                                    2006             3.510000
#                                                    2007             3.050000
#                                                    2008             2.570000
#                                                    2009             4.860000
#                                                    2010             3.320000
#                                                    2011             1.970000
#                                                    2012             2.160000
#                                                    2013             4.860000
#                                                    2014             2.290000
#                                                    2015             0.730000
#                                                    2016             7.380000
#                                                    2017             4.480000
#                                                    2018             3.570000
#                                                    2019             3.310000
# Coverage of protected areas in relation to mari... 2018             0.106210
# National ocean science expenditure as a share o... 2013             0.269060
# Protected marine area (Exclusive Economic Zones... 2018          2444.047360

# %%
# Defining function for line plot
def ind_line_plot(SeriesDescription):
    data2 = Ind_pivot14_1.loc[SeriesDescription]
    
    plt.plot(data2.index, data2.values)

# %%
ind_line_plot('Beach litter per square kilometer (Number)')

# %%
plt.figure(figsize = (18, 8))

ontinents = ['Beach litter per square kilometer (Number)','Chlorophyll-a anomaly, remote sensing (%)',
       'Chlorophyll-a deviations, remote sensing (%)',
       'Coverage of protected areas in relation to marine areas (Exclusive Economic Zones) (%)',
       'Protected marine area (Exclusive Economic Zones) (square kilometres)',
       'Average proportion of Marine Key Biodiversity Areas (KBAs) covered by protected areas (%)',
       'National ocean science expenditure as a share of total research and development funding (%)',]

for countinent in ontinents:
    ind_line_plot(countinent)

plt.legend(continents)

# %%
df_i.plot(kind='bar',x='SeriesDescription',y='Value')
plt.rcParams["figure.figsize"] = [14,12]

# %% [markdown]
# ## India Analysis

# %%
df_i= df5.loc[df5['GeoAreaName']=='India']
df_i.head()
# Out:
#            Goal Target       SeriesCode  \
# Indicator
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1  EN_MAR_BEALITSQ
# 14.1.1       14   14.1    EN_MAR_CHLANM
# 14.1.1       14   14.1    EN_MAR_CHLANM
#
#                                     SeriesDescription  GeoAreaCode  \
# Indicator
# 14.1.1     Beach litter per square kilometer (Number)          356
# 14.1.1     Beach litter per square kilometer (Number)          356
# 14.1.1     Beach litter per square kilometer (Number)          356
# 14.1.1      Chlorophyll-a anomaly, remote sensing (%)          356
# 14.1.1      Chlorophyll-a anomaly, remote sensing (%)          356
#
#           GeoAreaName TimePeriod         Value Time_Detail  UpperBound  \
# Indicator
# 14.1.1          India       2016  883222.00000        2016         0.0
# 14.1.1          India       2017  916969.00000        2017         0.0
# 14.1.1          India       2018  172809.00000        2018         0.0
# 14.1.1          India       2018       0.99071        2018         0.0
# 14.1.1          India       2018       1.44438        2018         0.0
#
#             ...       Freq Frequency of Chlorophyll-a concentration Location  \
# Indicator   ...
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...     ANNUAL                                        0  ALLAREA
# 14.1.1      ...          0                                     High        0
# 14.1.1      ...          0                                 Moderate        0
#
#           Nature Observation Status Reporting Type Sampling Stations  \
# Indicator
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  A              G                 0
# 14.1.1         E                  0              G                 0
# 14.1.1         E                  0              G                 0
#
#           Type of occupation Type of speed    Units
# Indicator
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                isco08          ANYS   NUMBER
# 14.1.1                     0             0  PERCENT
# 14.1.1                     0             0  PERCENT
#
# [5 rows x 23 columns]

# %%
df_i= df5.loc[df5['GeoAreaName']=='India']
Ind_pivot14_1=pd.pivot_table(df_i,index=["SeriesDescription","TimePeriod"],values=["Value"])
Ind_pivot14_1
# Out:
#                                                                        Value
# SeriesDescription                                  TimePeriod
# Average proportion of Marine Key Biodiversity A... 2000            18.802590
#                                                    2001            18.802590
#                                                    2002            18.802590
#                                                    2003            18.802590
#                                                    2004            18.802590
#                                                    2005            18.802590
#                                                    2006            18.802590
#                                                    2007            18.802590
#                                                    2008            18.802590
#                                                    2009            18.802590
#                                                    2010            18.802590
#                                                    2011            18.802590
#                                                    2012            18.802590
#                                                    2013            18.802590
#                                                    2014            18.802590
#                                                    2015            18.802590
#                                                    2016            18.802590
#                                                    2017            18.802590
#                                                    2018            18.802590
#                                                    2019            18.802590
# Beach litter per square kilometer (Number)         2016        883222.000000
#                                                    2017        916969.000000
#                                                    2018        172809.000000
# Chlorophyll-a anomaly, remote sensing (%)          2018             1.217545
#                                                    2019             1.858785
#                                                    2020             1.686675
# Chlorophyll-a deviations, remote sensing (%)       2000             3.360000
#                                                    2001             4.180000
#                                                    2002             4.640000
#                                                    2003             3.560000
#                                                    2004             4.760000
#                                                    2005             5.690000
#                                                    2006             3.510000
#                                                    2007             3.050000
#                                                    2008             2.570000
#                                                    2009             4.860000
#                                                    2010             3.320000
#                                                    2011             1.970000
#                                                    2012             2.160000
#                                                    2013             4.860000
#                                                    2014             2.290000
#                                                    2015             0.730000
#                                                    2016             7.380000
#                                                    2017             4.480000
#                                                    2018             3.570000
#                                                    2019             3.310000
# Coverage of protected areas in relation to mari... 2018             0.106210
# National ocean science expenditure as a share o... 2013             0.269060
# Protected marine area (Exclusive Economic Zones... 2018          2444.047360

# %%
# Defining function for line plot
def ind_line_plot(SeriesDescription):
    data2 = Ind_pivot14_1.loc[SeriesDescription]
    
    plt.plot(data2.index, data2.values)

# %%
plt.figure(figsize = (18, 8))

ontinents = ['Beach litter per square kilometer (Number)','Chlorophyll-a anomaly, remote sensing (%)',
       'Chlorophyll-a deviations, remote sensing (%)',
       'Coverage of protected areas in relation to marine areas (Exclusive Economic Zones) (%)',
       'Protected marine area (Exclusive Economic Zones) (square kilometres)',
       'Average proportion of Marine Key Biodiversity Areas (KBAs) covered by protected areas (%)',
       'National ocean science expenditure as a share of total research and development funding (%)',]

for countinent in ontinents:
    ind_line_plot(countinent)

plt.legend(continents)

# %%
df_i.plot(kind='bar',x='SeriesDescription',y='Value')
plt.rcParams["figure.figsize"] = [14,12]
